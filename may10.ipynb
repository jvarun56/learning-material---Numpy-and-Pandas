# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings(action='ignore')

# %%
sales_a = pd.Series([101,102,103,104,105,106])
sales_b = pd.Series([107,108,109,110,111,112])
df_prof_info_A = pd.DataFrame({
   'Emp_ID': [1001,1002,1003,1004,1005],
   'Name': ['Alex', 'Amy', 'Allen', 'Alice', 'Stephan'],
   'Gender':['M', 'F', 'M', 'F', 'M'],
   'Company':['Apple','Walmart','Intel','Cummins','Ford'],
   'Salary':[67000,90000,87000,69000,78000]},
   index=[101,102,103,104,105])
df_pers_info_A = pd.DataFrame({
     'Emp_ID': [1001,1002,1003,1004,1005],
   'Hometown': ['New York', 'London', 'San Francisco', 'Seattle', 'Madrid'],
     'Gender':['M', 'F', 'M', 'F', 'M'],
    'Marital':['Married','Divorsed','Single','Married','Single'],
   'Dependents':[1,1,3,2,1]},
   index=[101,102,103,104,105])

# %%
sales_a = pd.Series([101,102,103,104,105,106])
sales_b = pd.Series([107,108,109,110,111,112])

# %%
pd.concat([sales_a,sales_b],axis=0,ignore_index=True)
# Out:
# 0     101
# 1     102
# 2     103
# 3     104
# 4     105
# 5     106
# 6     107
# 7     108
# 8     109
# 9     110
# 10    111
# 11    112
# dtype: int64

# %%
pd.concat([sales_a,sales_b],axis=1)
# Out:
#      0    1
# 0  101  107
# 1  102  108
# 2  103  109
# 3  104  110
# 4  105  111
# 5  106  112

# %%
sales_swiggy = pd.Series([101,102,103,104,105,106])
sales_zomato = pd.Series([107,108,109,110,111,112])

# %%
a=pd.concat([sales_swiggy,sales_zomato],axis=0,keys=['swiggy','zomato'])

# %%
a
# Out:
# swiggy  0    101
#         1    102
#         2    103
#         3    104
#         4    105
#         5    106
# zomato  0    107
#         1    108
#         2    109
#         3    110
#         4    111
#         5    112
# dtype: int64

# %%
a.loc['zomato'][2:5]
# Out:
# 2    109
# 3    110
# 4    111
# dtype: int64

# %%
df_prof_info_A
# Out:
#      Emp_ID     Name Gender  Company  Salary
# 101    1001     Alex      M    Apple   67000
# 102    1002      Amy      F  Walmart   90000
# 103    1003    Allen      M    Intel   87000
# 104    1004    Alice      F  Cummins   69000
# 105    1005  Stephan      M     Ford   78000

# %%
df_pers_info_A
# Out:
#      Emp_ID       Hometown Gender   Marital  Dependents
# 101    1001       New York      M   Married           1
# 102    1002         London      F  Divorsed           1
# 103    1003  San Francisco      M    Single           3
# 104    1004        Seattle      F   Married           2
# 105    1005         Madrid      M    Single           1

# %%
df_pers_info_A.drop('Gender',axis=1,inplace=True)

# %%
df_pers_info_A
# Out:
#      Emp_ID       Hometown   Marital  Dependents
# 101    1001       New York   Married           1
# 102    1002         London  Divorsed           1
# 103    1003  San Francisco    Single           3
# 104    1004        Seattle   Married           2
# 105    1005         Madrid    Single           1

# %%
df_prof_info_A
# Out:
#      Emp_ID     Name Gender  Company  Salary
# 101    1001     Alex      M    Apple   67000
# 102    1002      Amy      F  Walmart   90000
# 103    1003    Allen      M    Intel   87000
# 104    1004    Alice      F  Cummins   69000
# 105    1005  Stephan      M     Ford   78000

# %%
pd.merge(df_prof_info_A,df_pers_info_A,on='Emp_ID')
# Out:
#    Emp_ID     Name Gender  Company  Salary       Hometown   Marital  \
# 0    1001     Alex      M    Apple   67000       New York   Married
# 1    1002      Amy      F  Walmart   90000         London  Divorsed
# 2    1003    Allen      M    Intel   87000  San Francisco    Single
# 3    1004    Alice      F  Cummins   69000        Seattle   Married
# 4    1005  Stephan      M     Ford   78000         Madrid    Single
#
#    Dependents
# 0           1
# 1           1
# 2           3
# 3           2
# 4           1

# %%
pd.concat([df_prof_info_A,df_pers_info_A],axis=0)
# Out:
#      Emp_ID     Name Gender  Company   Salary       Hometown   Marital  \
# 101    1001     Alex      M    Apple  67000.0            NaN       NaN
# 102    1002      Amy      F  Walmart  90000.0            NaN       NaN
# 103    1003    Allen      M    Intel  87000.0            NaN       NaN
# 104    1004    Alice      F  Cummins  69000.0            NaN       NaN
# 105    1005  Stephan      M     Ford  78000.0            NaN       NaN
# 101    1001      NaN    NaN      NaN      NaN       New York   Married
# 102    1002      NaN    NaN      NaN      NaN         London  Divorsed
# 103    1003      NaN    NaN      NaN      NaN  San Francisco    Single
# 104    1004      NaN    NaN      NaN      NaN        Seattle   Married
# 105    1005      NaN    NaN      NaN      NaN         Madrid    Single
#
#      Dependents
# 101         NaN
# 102         NaN
# 103         NaN
# 104         NaN
# 105         NaN
# 101         1.0
# 102         1.0
# 103         3.0
# 104         2.0
# ...

# %%
pd.concat([df_prof_info_A,df_pers_info_A],axis=1)
# Out:
#      Emp_ID     Name Gender  Company  Salary  Emp_ID       Hometown   Marital  \
# 101    1001     Alex      M    Apple   67000    1001       New York   Married
# 102    1002      Amy      F  Walmart   90000    1002         London  Divorsed
# 103    1003    Allen      M    Intel   87000    1003  San Francisco    Single
# 104    1004    Alice      F  Cummins   69000    1004        Seattle   Married
# 105    1005  Stephan      M     Ford   78000    1005         Madrid    Single
#
#      Dependents
# 101           1
# 102           1
# 103           3
# 104           2
# 105           1

# %%
df_pers_info_A
# Out:
#      Emp_ID       Hometown   Marital  Dependents
# 101    1001       New York   Married           1
# 102    1002         London  Divorsed           1
# 103    1003  San Francisco    Single           3
# 104    1004        Seattle   Married           2
# 105    1005         Madrid    Single           1

# %%
df_prof_info_A
# Out:
#      Emp_ID     Name Gender  Company  Salary
# 101    1001     Alex      M    Apple   67000
# 102    1002      Amy      F  Walmart   90000
# 103    1003    Allen      M    Intel   87000
# 104    1004    Alice      F  Cummins   69000
# 105    1005  Stephan      M     Ford   78000

# %%
df_prof_info_A = pd.DataFrame({
   'Emp_ID': [1001,1002,1003,1004,1005],
   'Name': ['Alex', 'Amy', 'Allen', 'Alice', 'Stephan'],
   'Gender':['M', 'F', 'M', 'F', 'M'],
   'Company':['Apple','Walmart','Intel','Cummins','Ford'],
   'Salary':[67000,90000,87000,69000,78000]},
   index=[101,102,103,104,105])
df_pers_info_A = pd.DataFrame({
     'Emp_ID': [1001,1002,1003,1004,1005],
   'Hometown': ['New York', 'London', 'San Francisco', 'Seattle', 'Madrid'],
     'Gender':['M', 'F', 'M', 'F', 'M'],
    'Marital':['Married','Divorsed','Single','Married','Single'],
   'Dependents':[1,1,3,2,1]},
   index=[101,102,103,104,105])

# %%
df_prof_info_A
# Out:
#      Emp_ID     Name Gender  Company  Salary
# 101    1001     Alex      M    Apple   67000
# 102    1002      Amy      F  Walmart   90000
# 103    1003    Allen      M    Intel   87000
# 104    1004    Alice      F  Cummins   69000
# 105    1005  Stephan      M     Ford   78000

# %%
df_pers_info_A
# Out:
#      Emp_ID       Hometown Gender   Marital  Dependents
# 101    1001       New York      M   Married           1
# 102    1002         London      F  Divorsed           1
# 103    1003  San Francisco      M    Single           3
# 104    1004        Seattle      F   Married           2
# 105    1005         Madrid      M    Single           1

# %%
pd.merge(df_prof_info_A,df_pers_info_A,on=['Emp_ID','Gender'],how='right')
# Out:
#    Emp_ID     Name Gender  Company  Salary       Hometown   Marital  \
# 0    1001     Alex      M    Apple   67000       New York   Married
# 1    1002      Amy      F  Walmart   90000         London  Divorsed
# 2    1003    Allen      M    Intel   87000  San Francisco    Single
# 3    1004    Alice      F  Cummins   69000        Seattle   Married
# 4    1005  Stephan      M     Ford   78000         Madrid    Single
#
#    Dependents
# 0           1
# 1           1
# 2           3
# 3           2
# 4           1

# %%
inner= intersection
outer=union
left=give pref to the first
right=give pref to the second data frame

# %%
data1=pd.DataFrame({'A':[10,20,30,50,60,56,90],'B':[20,30,50,60,10,89,90]})

# %%
data1
# Out:
#     A   B
# 0  10  20
# 1  20  30
# 2  30  50
# 3  50  60
# 4  60  10
# 5  56  89
# 6  90  90

# %%
data2=pd.DataFrame({'C':[10,20,30,50,60],'B':[20,30,50,60,10]})

# %%
data2
# Out:
#     C   B
# 0  10  20
# 1  20  30
# 2  30  50
# 3  50  60
# 4  60  10

# %%
pd.merge(data1,data2,on=['B'],how='inner')# intersection
# Out:
#     A   B   C
# 0  10  20  10
# 1  20  30  20
# 2  30  50  30
# 3  50  60  50
# 4  60  10  60

# %%
pd.merge(data1,data2,on=['B'],how='outer')# union
# Out:
#     A   B     C
# 0  10  20  10.0
# 1  20  30  20.0
# 2  30  50  30.0
# 3  50  60  50.0
# 4  60  10  60.0
# 5  56  89   NaN
# 6  90  90   NaN

# %%
pd.merge(data1,data2,on=['B'],how='left')
# Out:
#     A   B     C
# 0  10  20  10.0
# 1  20  30  20.0
# 2  30  50  30.0
# 3  50  60  50.0
# 4  60  10  60.0
# 5  56  89   NaN
# 6  90  90   NaN

# %%
pd.merge(data1,data2,on=['B'],how='right')
# Out:
#     A   B   C
# 0  10  20  10
# 1  20  30  20
# 2  30  50  30
# 3  50  60  50
# 4  60  10  60

# %%
# if all columns are same==> concat, axis=0, axis=1
#if min 1 common column==> merge,left, right, outer, inner
#multiindex

# %%
data = { 'Name':['Anne','Bobby','James','Lewis','Ross','Cathrine',
            'Anne','Bobby','Jack','Alisa','Alex','Cathrine'],
    'Company':['Apple','Walmart','Walmart','Intel','Apple','Walmart','Apple',
               'Cognizant','Apple','Apple','Cognizant','Walmart'],
    'Salary':[8500, 6300, 5500, 7400, 3100, 7700, 8500, 6300, 4200, 6200, 8900, 7700]}


df_employee = pd.DataFrame(data, columns=['Name','Company','Salary'])
df_employee
# Out:
#         Name    Company  Salary
# 0       Anne      Apple    8500
# 1      Bobby    Walmart    6300
# 2      James    Walmart    5500
# 3      Lewis      Intel    7400
# 4       Ross      Apple    3100
# 5   Cathrine    Walmart    7700
# 6       Anne      Apple    8500
# 7      Bobby  Cognizant    6300
# 8       Jack      Apple    4200
# 9      Alisa      Apple    6200
# 10      Alex  Cognizant    8900
# 11  Cathrine    Walmart    7700

# %%
abc=pd.MultiIndex.from_product([['Before GL','After GL'],['Python']])
marks=[[23,34],[56,67],[78,89]]

q=pd.DataFrame(marks,index=['Alisa','James','Smith'],columns=abc)

# %%
q
# Out:
#       Before GL After GL
#          Python   Python
# Alisa        23       34
# James        56       67
# Smith        78       89

# %%
p1=q.stack(level=0)
p1
# Out:
#                  Python
# Alisa After GL       34
#       Before GL      23
# James After GL       67
#       Before GL      56
# Smith After GL       89
#       Before GL      78

# %%
p2=q.stack(level=1)
p2
# Out:
#               After GL  Before GL
# Alisa Python        34         23
# James Python        67         56
# Smith Python        89         78

# %%
p1
# Out:
#                  Python
# Alisa After GL       34
#       Before GL      23
# James After GL       67
#       Before GL      56
# Smith After GL       89
#       Before GL      78

# %%
p1.loc['James'].loc['Before GL']=57

# %%
p2
# Out:
#               After GL  Before GL
# Alisa Python        34         23
# James Python        67         56
# Smith Python        89         78

# %%
p2.loc['Smith']['Before GL']
# Out:
# Python    78
# Name: Before GL, dtype: int64

# %%
p1
# Out:
#                  Python
# Alisa After GL       34
#       Before GL      23
# James After GL       67
#       Before GL      57
# Smith After GL       89
#       Before GL      78

# %%
po=p1.unstack()

# %%
po
# Out:
#         Python
#       After GL Before GL
# Alisa       34        23
# James       67        57
# Smith       89        78

# %%
data
# Out:
# {'Name': ['Anne',
#   'Bobby',
#   'James',
#   'Lewis',
#   'Ross',
#   'Cathrine',
#   'Anne',
#   'Bobby',
#   'Jack',
#   'Alisa',
#   'Alex',
#   'Cathrine'],
#  'Company': ['Apple',
#   'Walmart',
#   'Walmart',
#   'Intel',
#   'Apple',
#   'Walmart',
#   'Apple',
#   'Cognizant',
#   'Apple',
#   'Apple',
#   'Cognizant',
#   'Walmart'],
#  'Salary': [8500,
#   6300,
#   5500,
#   7400,
#   3100,
#   7700,
#   8500,
#   6300,
#   4200,
#   6200,
#   8900,
#   7700]}

# %%
df_employee # structured data
# Out:
#         Name    Company  Salary
# 0       Anne      Apple    8500
# 1      Bobby    Walmart    6300
# 2      James    Walmart    5500
# 3      Lewis      Intel    7400
# 4       Ross      Apple    3100
# 5   Cathrine    Walmart    7700
# 6       Anne      Apple    8500
# 7      Bobby  Cognizant    6300
# 8       Jack      Apple    4200
# 9      Alisa      Apple    6200
# 10      Alex  Cognizant    8900
# 11  Cathrine    Walmart    7700

# %%
pd.melt(df_employee,id_vars=['Name']) # unstruct
# Out:
#         Name variable      value
# 0       Anne  Company      Apple
# 1      Bobby  Company    Walmart
# 2      James  Company    Walmart
# 3      Lewis  Company      Intel
# 4       Ross  Company      Apple
# 5   Cathrine  Company    Walmart
# 6       Anne  Company      Apple
# 7      Bobby  Company  Cognizant
# 8       Jack  Company      Apple
# 9      Alisa  Company      Apple
# 10      Alex  Company  Cognizant
# 11  Cathrine  Company    Walmart
# 12      Anne   Salary       8500
# 13     Bobby   Salary       6300
# 14     James   Salary       5500
# 15     Lewis   Salary       7400
# 16      Ross   Salary       3100
# 17  Cathrine   Salary       7700
# 18      Anne   Salary       8500
# 19     Bobby   Salary       6300
# 20      Jack   Salary       4200
# 21     Alisa   Salary       6200
# 22      Alex   Salary       8900
# 23  Cathrine   Salary       7700

# %%
df_employee[df_employee.duplicated()]
# Out:
#         Name  Company  Salary
# 6       Anne    Apple    8500
# 11  Cathrine  Walmart    7700

# %%
df_employee.drop_duplicates()
# Out:
#         Name    Company  Salary
# 0       Anne      Apple    8500
# 1      Bobby    Walmart    6300
# 2      James    Walmart    5500
# 3      Lewis      Intel    7400
# 4       Ross      Apple    3100
# 5   Cathrine    Walmart    7700
# 7      Bobby  Cognizant    6300
# 8       Jack      Apple    4200
# 9      Alisa      Apple    6200
# 10      Alex  Cognizant    8900

# %%
df_employee.drop_duplicates(inplace=True,keep='first')

# %%
df_employee.drop_duplicates()
# Out:
#         Name    Company  Salary
# 0       Anne      Apple    8500
# 1      Bobby    Walmart    6300
# 2      James    Walmart    5500
# 3      Lewis      Intel    7400
# 4       Ross      Apple    3100
# 5   Cathrine    Walmart    7700
# 7      Bobby  Cognizant    6300
# 8       Jack      Apple    4200
# 9      Alisa      Apple    6200
# 10      Alex  Cognizant    8900

# %%
df_employee
# Out:
#         Name    Company  Salary
# 0       Anne      Apple    8500
# 1      Bobby    Walmart    6300
# 2      James    Walmart    5500
# 3      Lewis      Intel    7400
# 4       Ross      Apple    3100
# 5   Cathrine    Walmart    7700
# 7      Bobby  Cognizant    6300
# 8       Jack      Apple    4200
# 9      Alisa      Apple    6200
# 10      Alex  Cognizant    8900

# %%
df_employee.drop_duplicates(['Company'])
# Out:
#     Name    Company  Salary
# 0   Anne      Apple    8500
# 1  Bobby    Walmart    6300
# 3  Lewis      Intel    7400
# 7  Bobby  Cognizant    6300

# %%
df_employee.drop_duplicates(['Name','Company'])
# Out:
#         Name    Company  Salary
# 0       Anne      Apple    8500
# 1      Bobby    Walmart    6300
# 2      James    Walmart    5500
# 3      Lewis      Intel    7400
# 4       Ross      Apple    3100
# 5   Cathrine    Walmart    7700
# 7      Bobby  Cognizant    6300
# 8       Jack      Apple    4200
# 9      Alisa      Apple    6200
# 10      Alex  Cognizant    8900

# %%
df_employee
# Out:
#         Name    Company  Salary
# 0       Anne      Apple    8500
# 1      Bobby    Walmart    6300
# 2      James    Walmart    5500
# 3      Lewis      Intel    7400
# 4       Ross      Apple    3100
# 5   Cathrine    Walmart    7700
# 7      Bobby  Cognizant    6300
# 8       Jack      Apple    4200
# 9      Alisa      Apple    6200
# 10      Alex  Cognizant    8900

# %%
df_employee[df_employee.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Name, Company, Salary]
# Index: []

# %%
data=pd.read_csv('car_data.csv')

# %%
# mid term examination

# %%
data.head(3)
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0

# %%
data.tail(2)
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 299     city  2017           11.5           12.5        9000    Diesel
# 300     brio  2016            5.3            5.9        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 299      Dealer       Manual      0
# 300      Dealer       Manual      0

# %%
sample=data.sample(3)

# %%
sample
# Out:
#              Car_Name  Year  Selling_Price  Present_Price  Kms_Driven  \
# 55      corolla altis  2009           3.60          15.04       70000
# 212             creta  2016          11.25          13.60       22671
# 174  Honda CB Unicorn  2015           0.38           0.72       38600
#
#     Fuel_Type Seller_Type Transmission  Owner
# 55     Petrol      Dealer    Automatic      0
# 212    Petrol      Dealer       Manual      0
# 174    Petrol  Individual       Manual      0

# %%
What are the no of rows and columns?
# Out:
# Object `columns` not found.

# %%
What are the no of rows and columns

# %%
data.shape
# Out:
# (301, 9)

# %%
there are 301 rows and 9 columns
# Out:
#   File "<ipython-input-66-2fc25a58b5f0>", line 1
#     there are 301 rows and 9 columns
#           ^
# SyntaxError: invalid syntax

# %%
tell us the five point summary of your data set?

# %%
tell us the five point summary of your data set

# %%
data.describe()
# Out:
#               Year  Selling_Price  Present_Price     Kms_Driven       Owner
# count   301.000000     301.000000     301.000000     301.000000  301.000000
# mean   2013.627907       4.661296       7.628472   36947.205980    0.043189
# std       2.891554       5.082812       8.644115   38886.883882    0.247915
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.900000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.600000       6.400000   32000.000000    0.000000
# 75%    2016.000000       6.000000       9.900000   48767.000000    0.000000
# max    2018.000000      35.000000      92.600000  500000.000000    3.000000

# %%
which command in NPV gives you info about data type?

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       301 non-null    object
#  1   Year           301 non-null    int64
#  2   Selling_Price  301 non-null    float64
#  3   Present_Price  301 non-null    float64
#  4   Kms_Driven     301 non-null    int64
#  5   Fuel_Type      301 non-null    object
#  6   Seller_Type    301 non-null    object
#  7   Transmission   301 non-null    object
#  8   Owner          301 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 21.3+ KB

# %%
data.dtypes
# Out:
# Car_Name          object
# Year               int64
# Selling_Price    float64
# Present_Price    float64
# Kms_Driven         int64
# Fuel_Type         object
# Seller_Type       object
# Transmission      object
# Owner              int64
# dtype: object

# %%
data.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
what are the unique fuel type in you data?

# %%
data['Fuel_Type'].unique()
# Out:
# array(['Petrol', 'Diesel', 'CNG'], dtype=object)

# %%
the unique fuel are p, d ,cng

# %%
how many unique fuel type are there?

# %%
data['Fuel_Type'].nunique()
# Out:
# 3

# %%
how many cars we have which run on petrol?

# %%
data[data['Fuel_Type']=='Petrol']['Fuel_Type'].count()
# Out:
# 239

# %%
data['Fuel_Type'].value_counts()
# Out:
# Petrol    239
# Diesel     60
# CNG         2
# Name: Fuel_Type, dtype: int64

# %% [markdown]
# there are 239 cars running on petrol.

# %%
data.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
what are the different transmission engine type in your data?

# %%
data['Transmission'].unique()
# Out:
# array(['Manual', 'Automatic'], dtype=object)

# %%
hoe many unique ?

# %%
data['Transmission'].nunique()
# Out:
# 2

# %%
which are the top 10 costliest cars in your dataset?

# %%
data.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
a=data.sort_values('Present_Price',ascending=False)

# %%
which are the  10 cheapest cars in your dataset?

# %%
data.sort_values('Present_Price',ascending=True)['Car_Name'].head(10)
# Out:
# 195             Bajaj  ct 100
# 183        Bajaj Discover 100
# 181        Hero Splender Plus
# 187          Honda CB twister
# 180    Hero Honda Passion Pro
# 197          Honda CB twister
# 159           Honda Activa 4G
# 173                 Activa 4g
# 155           Honda Activa 4G
# 186                  TVS Wego
# Name: Car_Name, dtype: object

# %%
according to present price,

# %%
data.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
which cars are running on CNG in you dataset?

# %%
data[data['Fuel_Type']=='CNG']['Car_Name']
# Out:
# 18    wagon r
# 35        sx4
# Name: Car_Name, dtype: object

# %%
what is the average kms driven by wagon r?

# %%
data.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
data[data['Car_Name']=='wagon r']['Kms_Driven'].mean()
# Out:
# 40644.75

# %%
the the average kms driven by wagon r is 40644.75

# %%
what is the minimum price of ciaz in your dataset? can you tell in which year it was purchased?

# %%
data[data['Car_Name']=='ciaz']['Present_Price'].min()
# Out:
# 8.12

# %%
data[data['Car_Name']=='ciaz']
# Out:
#    Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 2      ciaz  2017           7.25           9.85        6900    Petrol
# 6      ciaz  2015           6.75           8.12       18796    Petrol
# 8      ciaz  2016           8.75           8.89       20273    Diesel
# 9      ciaz  2015           7.45           8.92       42367    Diesel
# 11     ciaz  2015           6.85          10.38       51000    Diesel
# 12     ciaz  2015           7.50           9.94       15000    Petrol
# 29     ciaz  2015           7.45          10.38       45000    Diesel
# 45     ciaz  2014           7.50          12.04       15000    Petrol
# 49     ciaz  2017           7.75           9.29       37000    Petrol
#
#    Seller_Type Transmission  Owner
# 2       Dealer       Manual      0
# 6       Dealer       Manual      0
# 8       Dealer       Manual      0
# 9       Dealer       Manual      0
# 11      Dealer       Manual      0
# 12      Dealer    Automatic      0
# ...

# %%
data[data['Present_Price']==8.12]['Year']
# Out:
# 6    2015
# Name: Year, dtype: int64

# %%
which cars are purchased through a dealer?

# %%
data['Seller_Type'].unique()
# Out:
# array(['Dealer', 'Individual'], dtype=object)

# %%
data[data['Seller_Type']=='Dealer']['Car_Name'].unique()
# Out:
# array(['ritz', 'sx4', 'ciaz', 'wagon r', 'swift', 'vitara brezza',
#        's cross', 'alto 800', 'ertiga', 'dzire', 'alto k10', 'ignis',
#        'baleno', 'omni', 'fortuner', 'innova', 'corolla altis',
#        'etios cross', 'etios g', 'etios liva', 'corolla', 'etios gd',
#        'land cruiser', 'i20', 'grand i10', 'i10', 'eon', 'xcent',
#        'elantra', 'creta', 'verna', 'city', 'brio', 'amaze', 'jazz'],
#       dtype=object)

# %% [raw]
# How many cars were purchased in a period from 2015 to 2018? How many kms on an avergae have these cars been running? which is the costliest car amongst them? (3 marks)

# %%
data.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
data[(data['Year']>=2015) & (data['Year']<=2018)]['Car_Name'].count()
# Out:
# 147

# %%
data[(data['Year']>=2015) & (data['Year']<=2018)]['Kms_Driven'].mean()
# Out:
# 22073.414965986394

# %%
data1=data[(data['Year']>=2015) & (data['Year']<=2018)]

# %%
data1[data1['Present_Price']==36.23]['Car_Name']
# Out:
# 64    fortuner
# Name: Car_Name, dtype: object

# %%
one moe live data
