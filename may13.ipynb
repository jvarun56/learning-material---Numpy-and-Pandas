# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data=sns.load_dataset("tips")

# %%
data.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
data1=data.rename({'total_bill':'total'})

# %%
a=sns.countplot(x='sex',data=data)

# %%
a.set_label("graph")

# %%
plt.pie(data.day.value_counts(), autopct = '%.2f%%', radius = 1.2, labels = ['Sat', 'Sun','Thur','Fri'])

circle =  plt.Circle( (0,0), radius = 0.5, color='white')
plot = plt.gcf()
plot.gca().add_artist(circle)

plt.show()

# %%
data.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
plt.boxplot(data['tip'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1ecde653310>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1ecde6539d0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1ecde641f70>],
#  'medians': [<matplotlib.lines.Line2D at 0x1ecde65d0d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1ecde65d430>],
#  'means': []}

# %%
data.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.violinplot(x='day',y='tip',data=data)

# %%
data2=sns.load_dataset("iris")

# %%
data2.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.scatterplot(x='sepal_length',y='sepal_width',data=data2)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %%
data2.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.distplot(data2['petal_length'])
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='petal_length', ylabel='Density'>

# %%
sns.barplot(x='species',y='petal_length',data=data2)
# Out:
# <AxesSubplot:xlabel='species', ylabel='petal_length'>

# %%
sns.pairplot(data2)

# %%
sns.heatmap(data2.isnull())
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(data2.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.swarmplot(x='species',y='petal_length',data=data2)

# %%
sns.stripplot(x='species',y='petal_length',data=data2)

# %%
sns.boxplot(x='species',y='petal_length',data=data2)

# %%
data2.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
data2['species'].value_counts()
# Out:
# virginica     50
# setosa        50
# versicolor    50
# Name: species, dtype: int64

# %%
data2.species.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
plt.pie(data2.species.value_counts(),labels=['virginica','setosa','versocolor'],autopct="%0.2f%%")
# Out:
# ([<matplotlib.patches.Wedge at 0x1ece0b95fa0>,
# ...
#  [Text(0.5499999702695115, 0.9526279613277875, 'virginica'),
#   Text(-1.0999999999999954, -1.0298943258065002e-07, 'setosa'),
#   Text(0.5500001486524352, -0.9526278583383436, 'versocolor')],
#  [Text(0.2999999837833699, 0.5196152516333385, '33.33%'),
#   Text(-0.5999999999999974, -5.6176054134900006e-08, '33.33%'),
#   Text(0.30000008108314646, -0.5196151954572783, '33.33%')])

# %%
data2.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.lineplot(x='petal_length',y='petal_width',data=data2,hue='species')
# Out:
# <AxesSubplot:xlabel='petal_length', ylabel='petal_width'>
