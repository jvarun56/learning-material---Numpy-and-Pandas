# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings(action='ignore')

# %%
data=pd.read_csv("basic_info.csv") # when jupyter notebook and your file are at the same loc

# %%
data
# Out:
#     Age  Weight (in kg)  Height (in m)
# 0    45              60           1.35
# 1    12              43           1.21
# 2    54              78           1.50
# 3    26              65           1.21
# 4    68              50           1.32
# 5    21              43           1.52
# 6    10              32           1.65
# 7    57              34           1.61
# 8    75              23           1.24
# 9    32              21           1.52
# 10   23              53           1.50
# 11   34              65           1.76
# 12   55              89           1.65
# 13   23              45           1.75
# 14   56              76           1.69
# 15   67              78           1.85
# 16   26              65           1.21
# 17   56              74           1.69
# 18   67              78           1.85
# 19   26              65           1.21
# 20   68              50           1.32
# 21   56              76           1.69
# 22   67              78           1.85

# %%
#data2=pd.read_csv('C:\\Users\\shamb\\Desktop\\basic_info.csv')
data2=pd.read_csv('basic_info.csv')

# %%
data2
# Out:
#     Age  Weight (in kg)  Height (in m)
# 0    45              60           1.35
# 1    12              43           1.21
# 2    54              78           1.50
# 3    26              65           1.21
# 4    68              50           1.32
# 5    21              43           1.52
# 6    10              32           1.65
# 7    57              34           1.61
# 8    75              23           1.24
# 9    32              21           1.52
# 10   23              53           1.50
# 11   34              65           1.76
# 12   55              89           1.65
# 13   23              45           1.75
# 14   56              76           1.69
# 15   67              78           1.85
# 16   26              65           1.21
# 17   56              74           1.69
# 18   67              78           1.85
# 19   26              65           1.21
# 20   68              50           1.32
# 21   56              76           1.69
# 22   67              78           1.85

# %%
pwd
# Out:
# 'C:\\Users\\VARUN JAIN\\Desktop\\Jupiter - Notebook\\Class Notes\\Numpy,Pandas & Visualization'

# %%
data
# Out:
#     Age  Weight (in kg)  Height (in m)
# 0    45              60           1.35
# 1    12              43           1.21
# 2    54              78           1.50
# 3    26              65           1.21
# 4    68              50           1.32
# 5    21              43           1.52
# 6    10              32           1.65
# 7    57              34           1.61
# 8    75              23           1.24
# 9    32              21           1.52
# 10   23              53           1.50
# 11   34              65           1.76
# 12   55              89           1.65
# 13   23              45           1.75
# 14   56              76           1.69
# 15   67              78           1.85
# 16   26              65           1.21
# 17   56              74           1.69
# 18   67              78           1.85
# 19   26              65           1.21
# 20   68              50           1.32
# 21   56              76           1.69
# 22   67              78           1.85

# %%
data.head(3)
# Out:
#    Age  Weight (in kg)  Height (in m)
# 0   45              60           1.35
# 1   12              43           1.21
# 2   54              78           1.50

# %%
data.sample(3)
# Out:
#     Age  Weight (in kg)  Height (in m)
# 12   55              89           1.65
# 20   68              50           1.32
# 17   56              74           1.69

# %%
data.tail()
# Out:
#     Age  Weight (in kg)  Height (in m)
# 18   67              78           1.85
# 19   26              65           1.21
# 20   68              50           1.32
# 21   56              76           1.69
# 22   67              78           1.85

# %%
data
# Out:
#     Age  Weight (in kg)  Height (in m)
# 0    45              60           1.35
# 1    12              43           1.21
# 2    54              78           1.50
# 3    26              65           1.21
# 4    68              50           1.32
# 5    21              43           1.52
# 6    10              32           1.65
# 7    57              34           1.61
# 8    75              23           1.24
# 9    32              21           1.52
# 10   23              53           1.50
# 11   34              65           1.76
# 12   55              89           1.65
# 13   23              45           1.75
# 14   56              76           1.69
# 15   67              78           1.85
# 16   26              65           1.21
# 17   56              74           1.69
# 18   67              78           1.85
# 19   26              65           1.21
# 20   68              50           1.32
# 21   56              76           1.69
# 22   67              78           1.85

# %%
create a new column called bmi=wt/ht**2
# Out:
#   File "<ipython-input-20-50104fca6886>", line 1
#     create a new column called bmi=wt/ht**2
#            ^
# SyntaxError: invalid syntax

# %%
data['bmi']=data['Weight (in kg)']/data['Height (in m)']**2

# %%
data
# Out:
#     Age  Weight (in kg)  Height (in m)        bmi
# 0    45              60           1.35  32.921811
# 1    12              43           1.21  29.369579
# 2    54              78           1.50  34.666667
# 3    26              65           1.21  44.395875
# 4    68              50           1.32  28.696051
# 5    21              43           1.52  18.611496
# 6    10              32           1.65  11.753903
# 7    57              34           1.61  13.116778
# 8    75              23           1.24  14.958377
# 9    32              21           1.52   9.089335
# 10   23              53           1.50  23.555556
# 11   34              65           1.76  20.983988
# 12   55              89           1.65  32.690542
# 13   23              45           1.75  14.693878
# 14   56              76           1.69  26.609713
# 15   67              78           1.85  22.790358
# 16   26              65           1.21  44.395875
# 17   56              74           1.69  25.909457
# ...

# %%
data.head()
# Out:
#    Age  Weight (in kg)  Height (in m)
# 0   45              60           1.35
# 1   12              43           1.21
# 2   54              78           1.50
# 3   26              65           1.21
# 4   68              50           1.32

# %%
data.drop('bmi',axis=1)
# Out:
#     Age  Weight (in kg)  Height (in m)
# 0    45              60           1.35
# 1    12              43           1.21
# 2    54              78           1.50
# 3    26              65           1.21
# 4    68              50           1.32
# 5    21              43           1.52
# 6    10              32           1.65
# 7    57              34           1.61
# 8    75              23           1.24
# 9    32              21           1.52
# 10   23              53           1.50
# 11   34              65           1.76
# 12   55              89           1.65
# 13   23              45           1.75
# 14   56              76           1.69
# 15   67              78           1.85
# 16   26              65           1.21
# 17   56              74           1.69
# 18   67              78           1.85
# 19   26              65           1.21
# 20   68              50           1.32
# 21   56              76           1.69
# 22   67              78           1.85

# %%
data.drop(0,axis=0)
# Out:
#     Age  Weight (in kg)  Height (in m)        bmi
# 1    12              43           1.21  29.369579
# 2    54              78           1.50  34.666667
# 3    26              65           1.21  44.395875
# 4    68              50           1.32  28.696051
# 5    21              43           1.52  18.611496
# 6    10              32           1.65  11.753903
# 7    57              34           1.61  13.116778
# 8    75              23           1.24  14.958377
# 9    32              21           1.52   9.089335
# 10   23              53           1.50  23.555556
# 11   34              65           1.76  20.983988
# 12   55              89           1.65  32.690542
# 13   23              45           1.75  14.693878
# 14   56              76           1.69  26.609713
# 15   67              78           1.85  22.790358
# 16   26              65           1.21  44.395875
# 17   56              74           1.69  25.909457
# 18   67              78           1.85  22.790358
# ...

# %%
data
# Out:
#     Age  Weight (in kg)  Height (in m)        bmi
# 0    45              60           1.35  32.921811
# 1    12              43           1.21  29.369579
# 2    54              78           1.50  34.666667
# 3    26              65           1.21  44.395875
# 4    68              50           1.32  28.696051
# 5    21              43           1.52  18.611496
# 6    10              32           1.65  11.753903
# 7    57              34           1.61  13.116778
# 8    75              23           1.24  14.958377
# 9    32              21           1.52   9.089335
# 10   23              53           1.50  23.555556
# 11   34              65           1.76  20.983988
# 12   55              89           1.65  32.690542
# 13   23              45           1.75  14.693878
# 14   56              76           1.69  26.609713
# 15   67              78           1.85  22.790358
# 16   26              65           1.21  44.395875
# 17   56              74           1.69  25.909457
# ...

# %%
data.drop('bmi',axis=1)
# Out:
#     Age  Weight (in kg)  Height (in m)
# 0    45              60           1.35
# 1    12              43           1.21
# 2    54              78           1.50
# 3    26              65           1.21
# 4    68              50           1.32
# 5    21              43           1.52
# 6    10              32           1.65
# 7    57              34           1.61
# 8    75              23           1.24
# 9    32              21           1.52
# 10   23              53           1.50
# 11   34              65           1.76
# 12   55              89           1.65
# 13   23              45           1.75
# 14   56              76           1.69
# 15   67              78           1.85
# 16   26              65           1.21
# 17   56              74           1.69
# 18   67              78           1.85
# 19   26              65           1.21
# 20   68              50           1.32
# 21   56              76           1.69
# 22   67              78           1.85

# %%
del data

# %%
data.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-304fa4ce4ebd> in <module>
# ----> 1 data.head()
#
# NameError: name 'data' is not defined

# %%
find out the data of people whose age is greater than 50 and height is greater than 1.21 m.
# Out:
#   File "<ipython-input-15-e4066668ca13>", line 1
#     find out the data of people whose age is greater than 50 and height is greater than 1.21 m.
#          ^
# SyntaxError: invalid syntax

# %%
result=data[(data['Age']>50) & (data['Height (in m)']>1.21)]

# %%
result
# Out:
#     Age  Weight (in kg)  Height (in m)
# 2    54              78           1.50
# 4    68              50           1.32
# 7    57              34           1.61
# 8    75              23           1.24
# 12   55              89           1.65
# 14   56              76           1.69
# 15   67              78           1.85
# 17   56              74           1.69
# 18   67              78           1.85
# 20   68              50           1.32
# 21   56              76           1.69
# 22   67              78           1.85

# %%
result.Age.sort_values()
# Out:
# 2     54
# 12    55
# 14    56
# 17    56
# 21    56
# 7     57
# 15    67
# 18    67
# 22    67
# 4     68
# 20    68
# 8     75
# Name: Age, dtype: int64

# %%
result.sort_values('Age',ascending=False)
# Out:
#     Age  Weight (in kg)  Height (in m)
# 8    75              23           1.24
# 4    68              50           1.32
# 20   68              50           1.32
# 15   67              78           1.85
# 18   67              78           1.85
# 22   67              78           1.85
# 7    57              34           1.61
# 14   56              76           1.69
# 17   56              74           1.69
# 21   56              76           1.69
# 12   55              89           1.65
# 2    54              78           1.50

# %%
res1=result[result['Age']==56]
res1['rank']=res1['Weight (in kg)'].rank(method='min')
res1[res1['rank']==1]
# Out:
#     Age  Weight (in kg)  Height (in m)  rank
# 17   56              74           1.69   1.0

# %%
res1
# Out:
#     Age  Weight (in kg)  Height (in m)  rank
# 14   56              76           1.69   2.0
# 17   56              74           1.69   1.0
# 21   56              76           1.69   2.0

# %%
count the number of people whose age is greater than 60.

# %%
data.head()
# Out:
#    Age  Weight (in kg)  Height (in m)        bmi
# 0   45              60           1.35  32.921811
# 1   12              43           1.21  29.369579
# 2   54              78           1.50  34.666667
# 3   26              65           1.21  44.395875
# 4   68              50           1.32  28.696051

# %%
data[data['Age']>60].count()
# Out:
# Age               6
# Weight (in kg)    6
# Height (in m)     6
# bmi               6
# dtype: int64

# %% [markdown]
# 6 people whose age is greter than 60

# %%
data[data['Age']>60]['Age'].count()
# Out:
# 6

# %%
what is the average wt in kg of the database.

# %%
data.head()
# Out:
#    Age  Weight (in kg)  Height (in m)        bmi
# 0   45              60           1.35  32.921811
# 1   12              43           1.21  29.369579
# 2   54              78           1.50  34.666667
# 3   26              65           1.21  44.395875
# 4   68              50           1.32  28.696051

# %%
data['Weight (in kg)'].mean()
# Out:
# 58.30434782608695

# %%
np.mean(data['Weight (in kg)'])
# Out:
# 58.30434782608695

# %%
the average

# %%
file2=pd.read_excel('employee_info.xlsx')

# %%
file2.head()
# Out:
#    Age  Gender  Salary
# 0   45    Male   40000
# 1   12    Male       0
# 2   54  Female  150000
# 3   26    Male   30000
# 4   64  Female   15000

# %%
find out how many males are working in your firm?
# Out:
# Object `firm` not found.

# %%
find out how many males are working in your firm

# %%
file2['Gender'].value_counts() # categorical columns
# Out:
# Female    3
# Male      3
# Name: Gender, dtype: int64

# %%
file2.Gender.value_counts()
# Out:
# Female    3
# Male      3
# Name: Gender, dtype: int64

# %%
there are 3 males

# %%
file2
# Out:
#    Age  Gender  Salary
# 0   45    Male   40000
# 1   12    Male       0
# 2   54  Female  150000
# 3   26    Male   30000
# 4   64  Female   15000
# 5   21  Female   25600

# %%
replace the 'Female' by 'female','Male' with 'male'
# Out:
#   File "<ipython-input-38-c086138e26db>", line 1
#     replace the 'Female' by 'female','Male' with 'male'
#             ^
# SyntaxError: invalid syntax

# %%
file2['Gender']=file2['Gender'].replace('Female','female')

# %%
file2['Gender']=file2['Gender'].replace('Male','male')

# %%
file2
# Out:
#    Age  Gender  Salary
# 0   45    male   40000
# 1   12    male       0
# 2   54  female  150000
# 3   26    male   30000
# 4   64  female   15000
# 5   21  female   25600

# %%
file2
# Out:
#    Age  Gender  Salary
# 0   45    male   40000
# 1   12    male       0
# 2   54  female  150000
# 3   26    male   30000
# 4   64  female   15000
# 5   21  female   25600

# %%
file2[file2['Gender']=='male']['Gender'].count()
# Out:
# 3

# %%
file2[file2['Gender']=='male'].count()
# Out:
# Age       3
# Gender    3
# Salary    3
# dtype: int64

# %%
file2[file2.Gender=='male'].count()
# Out:
# Age       0
# Gender    0
# Salary    0
# dtype: int64

# %%
df_demography = pd.DataFrame({'Country':['China','India','USA','Indonesia','Brazil'],
                  'Population':[1403500365,1324171354,322179605,261115456,207652865]})


df_demography
# Out:
#      Country  Population
# 0      China  1403500365
# 1      India  1324171354
# 2        USA   322179605
# 3  Indonesia   261115456
# 4     Brazil   207652865

# %%
capital = {
'Germany':'Berlin',
'Brazil':'Brasília',
'Hungary':'Budapest',
'China':'Beijing',
'India':'New Delhi',
'Norway':'Oslo',
'France':'Paris',
'Indonesia': 'Jakarta',
'USA':'Washington'
}

# %%
df_demography['capital']=df_demography['Country'].map(capital)

# %%
df_demography
# Out:
#      Country  Population     capital
# 0      China  1403500365     Beijing
# 1      India  1324171354   New Delhi
# 2        USA   322179605  Washington
# 3  Indonesia   261115456     Jakarta
# 4     Brazil   207652865    Brasília

# %%
df_products = pd.DataFrame({ 'Product_ID':[101,102,103,104,105,106],
 'Food_Product':['Cakes','Biscuits','Fruit','Beverages','Cakes','Beverages'],
 'Brand':['Baskin Robbins','Blue Riband','Peach','Horlicks','Mars Muffin','Mirinda'],
 'Sales': [5000, 8000, 7600, 5500, 6500, 9000],
 'Profit': [55000, 67000, 89000, 78000, 55000, 90000] })

# %%
df_products
# Out:
#    Product_ID Food_Product           Brand  Sales  Profit
# 0         101        Cakes  Baskin Robbins   5000   55000
# 1         102     Biscuits     Blue Riband   8000   67000
# 2         103        Fruit           Peach   7600   89000
# 3         104    Beverages        Horlicks   5500   78000
# 4         105        Cakes     Mars Muffin   6500   55000
# 5         106    Beverages         Mirinda   9000   90000

# %%
df1=df_products.groupby('Food_Product')

# %%
print(df1)

# %%
df1

# %%
df1.max()
# Out:
#               Product_ID        Brand  Sales  Profit
# Food_Product
# Beverages            106      Mirinda   9000   90000
# Biscuits             102  Blue Riband   8000   67000
# Cakes                105  Mars Muffin   6500   55000
# Fruit                103        Peach   7600   89000

# %%
what is the max profit earned by food products?
# Out:
# Object `products` not found.

# %%
df1=df_products.groupby('Food_Product')['Profit']

# %%
df1.max()
# Out:
# Food_Product
# Beverages    90000
# Biscuits     67000
# Cakes        55000
# Fruit        89000
# Name: Profit, dtype: int64

# %%
what was the tptal sales of the store? how much was the total sales?

# %%
df_products['Sales'].sum()
# Out:
# 41600

# %%
the totals sales is 41600.
# Out:
#   File "<ipython-input-60-93ac681672d9>", line 1
#     the totals sales is 41600.
#         ^
# SyntaxError: invalid syntax

# %%
df_products
# Out:
#    Product_ID Food_Product           Brand  Sales  Profit
# 0         101        Cakes  Baskin Robbins   5000   55000
# 1         102     Biscuits     Blue Riband   8000   67000
# 2         103        Fruit           Peach   7600   89000
# 3         104    Beverages        Horlicks   5500   78000
# 4         105        Cakes     Mars Muffin   6500   55000
# 5         106    Beverages         Mirinda   9000   90000

# %%
# pivot tables

# %%
pd.pivot_table(df_products,index=['Brand'],aggfunc=np.mean)
# Out:
#                 Product_ID  Profit  Sales
# Brand
# Baskin Robbins         101   55000   5000
# Blue Riband            102   67000   8000
# Horlicks               104   78000   5500
# Mars Muffin            105   55000   6500
# Mirinda                106   90000   9000
# Peach                  103   89000   7600

# %%
pd.pivot_table(df_products,index=['Brand'],values=['Profit','Sales'],aggfunc=np.min)
# Out:
#                 Profit  Sales
# Brand
# Baskin Robbins   55000   5000
# Blue Riband      67000   8000
# Horlicks         78000   5500
# Mars Muffin      55000   6500
# Mirinda          90000   9000
# Peach            89000   7600

# %%
pd.pivot_table(df_products,index=['Brand'],values=['Profit','Sales'],columns=['Food_Product'],aggfunc=np.min)
# Out:
#                   Profit                                Sales           \
# Food_Product   Beverages Biscuits    Cakes    Fruit Beverages Biscuits
# Brand
# Baskin Robbins       NaN      NaN  55000.0      NaN       NaN      NaN
# Blue Riband          NaN  67000.0      NaN      NaN       NaN   8000.0
# Horlicks         78000.0      NaN      NaN      NaN    5500.0      NaN
# Mars Muffin          NaN      NaN  55000.0      NaN       NaN      NaN
# Mirinda          90000.0      NaN      NaN      NaN    9000.0      NaN
# Peach                NaN      NaN      NaN  89000.0       NaN      NaN
#
#
# Food_Product     Cakes   Fruit
# Brand
# Baskin Robbins  5000.0     NaN
# Blue Riband        NaN     NaN
# Horlicks           NaN     NaN
# Mars Muffin     6500.0     NaN
# Mirinda            NaN     NaN
# Peach              NaN  7600.0

# %%
# pandas cross tab

# %%
df_products
# Out:
#    Product_ID Food_Product           Brand  Sales  Profit
# 0         101        Cakes  Baskin Robbins   5000   55000
# 1         102     Biscuits     Blue Riband   8000   67000
# 2         103        Fruit           Peach   7600   89000
# 3         104    Beverages        Horlicks   5500   78000
# 4         105        Cakes     Mars Muffin   6500   55000
# 5         106    Beverages         Mirinda   9000   90000

# %%
pd.crosstab(df_products['Brand'],df_products['Food_Product'])
# Out:
# Food_Product    Beverages  Biscuits  Cakes  Fruit
# Brand
# Baskin Robbins          0         0      1      0
# Blue Riband             0         1      0      0
# Horlicks                1         0      0      0
# Mars Muffin             0         0      1      0
# Mirinda                 1         0      0      0
# Peach                   0         0      0      1

# %%
pd.crosstab(df_products['Food_Product'],df_products['Brand'])
# Out:
# Brand         Baskin Robbins  Blue Riband  Horlicks  Mars Muffin  Mirinda  \
# Food_Product
# Beverages                  0            0         1            0        1
# Biscuits                   0            1         0            0        0
# Cakes                      1            0         0            1        0
# Fruit                      0            0         0            0        0
#
# Brand         Peach
# Food_Product
# Beverages         0
# Biscuits          0
# Cakes             0
# Fruit             1

# %%
df = pd.DataFrame(data={'Animal': ['cat', 'penguin', 'dog',
                                   'spider', 'snake'],
                        'Number_legs': [4, 2, 4, 8, np.nan]})

# %%
# data ranks

# %%
df
# Out:
#     Animal  Number_legs
# 0      cat          4.0
# 1  penguin          2.0
# 2      dog          4.0
# 3   spider          8.0
# 4    snake          NaN

# %%
df['default_rank']=df['Number_legs'].rank(method='average')

# %%
df
# Out:
#     Animal  Number_legs  default_rank
# 0      cat          4.0           2.5
# 1  penguin          2.0           1.0
# 2      dog          4.0           2.5
# 3   spider          8.0           4.0
# 4    snake          NaN           NaN

# %%
df['min_rank']=df['Number_legs'].rank(method='min')

# %%
df
# Out:
#     Animal  Number_legs  default_rank  min_rank
# 0      cat          4.0           2.5       2.0
# 1  penguin          2.0           1.0       1.0
# 2      dog          4.0           2.5       2.0
# 3   spider          8.0           4.0       4.0
# 4    snake          NaN           NaN       NaN

# %%
df['max_rank']=df['Number_legs'].rank(method='max')

# %%
df
# Out:
#     Animal  Number_legs  default_rank  min_rank  max_rank
# 0      cat          4.0           2.5       2.0       3.0
# 1  penguin          2.0           1.0       1.0       1.0
# 2      dog          4.0           2.5       2.0       3.0
# 3   spider          8.0           4.0       4.0       4.0
# 4    snake          NaN           NaN       NaN       NaN

# %%
df['na_rank']=df['Number_legs'].rank(method='average',na_option='bottom')

# %%
df
# Out:
#     Animal  Number_legs  default_rank  min_rank  max_rank  na_rank
# 0      cat          4.0           2.5       2.0       3.0      2.5
# 1  penguin          2.0           1.0       1.0       1.0      1.0
# 2      dog          4.0           2.5       2.0       3.0      2.5
# 3   spider          8.0           4.0       4.0       4.0      4.0
# 4    snake          NaN           NaN       NaN       NaN      5.0

# %%
df['na_rank_top']=df['Number_legs'].rank(method='average',na_option='top')

# %%
df
# Out:
#     Animal  Number_legs  default_rank  min_rank  max_rank  na_rank  \
# 0      cat          4.0           2.5       2.0       3.0      2.5
# 1  penguin          2.0           1.0       1.0       1.0      1.0
# 2      dog          4.0           2.5       2.0       3.0      2.5
# 3   spider          8.0           4.0       4.0       4.0      4.0
# 4    snake          NaN           NaN       NaN       NaN      5.0
#
#    na_rank_top
# 0          3.5
# 1          2.0
# 2          3.5
# 3          5.0
# 4          1.0

# %%
df['percet']=df['Number_legs'].rank(method='average',na_option='top',pct=True)

# %%
df
# Out:
#     Animal  Number_legs  default_rank  min_rank  max_rank  na_rank  \
# 0      cat          4.0           2.5       2.0       3.0      2.5
# 1  penguin          2.0           1.0       1.0       1.0      1.0
# 2      dog          4.0           2.5       2.0       3.0      2.5
# 3   spider          8.0           4.0       4.0       4.0      4.0
# 4    snake          NaN           NaN       NaN       NaN      5.0
#
#    na_rank_top  percet
# 0          3.5     0.7
# 1          2.0     0.4
# 2          3.5     0.7
# 3          5.0     1.0
# 4          1.0     0.2

# %%
df['dummy']=df['Number_legs'].rank(method='min',ascending=False)

# %%
df
# Out:
#     Animal  Number_legs  default_rank  min_rank  max_rank  na_rank  \
# 0      cat          4.0           2.5       2.0       3.0      2.5
# 1  penguin          2.0           1.0       1.0       1.0      1.0
# 2      dog          4.0           2.5       2.0       3.0      2.5
# 3   spider          8.0           4.0       4.0       4.0      4.0
# 4    snake          NaN           NaN       NaN       NaN      5.0
#
#    na_rank_top  percet  dummy
# 0          3.5     0.7    2.0
# 1          2.0     0.4    4.0
# 2          3.5     0.7    2.0
# 3          5.0     1.0    1.0
# 4          1.0     0.2    NaN
