# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings(action='ignore')

# %%
data=pd.read_csv('people.csv')

# %%
data.head()
# Out:
#    Age  Gender Hometown  Height  Qualification Smoker
# 0   45    Male   Mumbai     167       Graduate    Yes
# 1   23  Female   Mumbai     170       Graduate     No
# 2   27    Male   Mumbai     175  Post-graduate     No
# 3   34    Male    Delhi     155       Graduate     No
# 4   43  Female   Mumbai     157  Post-graduate    Yes

# %%
how many rows and cols?
# Out:
# Object `cols` not found.

# %%
data.shape
# Out:
# (21, 6)

# %%
what are the diif dtypes in you data?

# %%
data.dtypes
# Out:
# Age               int64
# Gender           object
# Hometown         object
# Height            int64
# Qualification    object
# Smoker           object
# dtype: object

# %%
find out 5 point summary/descriptive stats of your data
# Out:
#   File "<ipython-input-8-351ed52b34ab>", line 1
#     find out 5 point summary/descriptive stats of your data
#          ^
# SyntaxError: invalid syntax

# %%
data.describe()
# Out:
#              Age      Height
# count  21.000000   21.000000
# mean   42.333333  166.190476
# std    11.858893    8.919748
# min    21.000000  151.000000
# 25%    34.000000  158.000000
# 50%    43.000000  167.000000
# 75%    54.000000  175.000000
# max    59.000000  182.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Age            21 non-null     int64
#  1   Gender         21 non-null     object
#  2   Hometown       21 non-null     object
#  3   Height         21 non-null     int64
#  4   Qualification  21 non-null     object
#  5   Smoker         21 non-null     object
# dtypes: int64(2), object(4)
# memory usage: 1.1+ KB

# %%
data.head()
# Out:
#    Age  Gender Hometown  Height  Qualification Smoker
# 0   45    Male   Mumbai     167       Graduate    Yes
# 1   23  Female   Mumbai     170       Graduate     No
# 2   27    Male   Mumbai     175  Post-graduate     No
# 3   34    Male    Delhi     155       Graduate     No
# 4   43  Female   Mumbai     157  Post-graduate    Yes

# %%
how many females in your dataset are post graduates?
# Out:
# Object `graduates` not found.

# %%
how many females in your dataset are post graduates

# %%
data[(data['Gender']=='Female') & (data['Qualification']=='Post-graduate')].count()
# Out:
# Age              4
# Gender           4
# Hometown         4
# Height           4
# Qualification    4
# Smoker           4
# dtype: int64

# %%
what is the avergae height of males and females in your dataset. Use pivot.
# Out:
#   File "<ipython-input-14-222b605e2495>", line 1
#     what is the avergae height of males and females in your dataset. Use pivot.
#                 ^
# SyntaxError: invalid syntax

# %%
data.head()
# Out:
#    Age  Gender Hometown  Height  Qualification Smoker
# 0   45    Male   Mumbai     167       Graduate    Yes
# 1   23  Female   Mumbai     170       Graduate     No
# 2   27    Male   Mumbai     175  Post-graduate     No
# 3   34    Male    Delhi     155       Graduate     No
# 4   43  Female   Mumbai     157  Post-graduate    Yes

# %%
pd.pivot_table(data,index=['Gender'],values=['Height'],aggfunc=np.mean)
# Out:
#             Height
# Gender
# Female  162.800000
# Male    169.272727

# %%
data.groupby('Gender')['Height'].mean()
# Out:
# Gender
# Female    162.800000
# Male      169.272727
# Name: Height, dtype: float64

# %%
data.head()
# Out:
#    Age  Gender Hometown  Height  Qualification Smoker
# 0   45    Male   Mumbai     167       Graduate    Yes
# 1   23  Female   Mumbai     170       Graduate     No
# 2   27    Male   Mumbai     175  Post-graduate     No
# 3   34    Male    Delhi     155       Graduate     No
# 4   43  Female   Mumbai     157  Post-graduate    Yes

# %%
#using a melt function, convert strctured data into raw format.

# %%
pd.melt(data,id_vars='Qualification')
# Out:
#      Qualification variable value
# 0         Graduate      Age    45
# 1         Graduate      Age    23
# 2    Post-graduate      Age    27
# 3         Graduate      Age    34
# 4    Post-graduate      Age    43
# ..             ...      ...   ...
# 100       Graduate   Smoker    No
# 101        Diploma   Smoker    No
# 102       Graduate   Smoker   Yes
# 103  Post-graduate   Smoker   Yes
# 104  Post-graduate   Smoker    No
#
# [105 rows x 3 columns]

# %%
data.head()
# Out:
#    Age  Gender Hometown  Height  Qualification Smoker
# 0   45    Male   Mumbai     167       Graduate    Yes
# 1   23  Female   Mumbai     170       Graduate     No
# 2   27    Male   Mumbai     175  Post-graduate     No
# 3   34    Male    Delhi     155       Graduate     No
# 4   43  Female   Mumbai     157  Post-graduate    Yes

# %%
d1=data[['Age','Gender']]
d2=data[['Hometown','Height']]

# %%
d1
# Out:
#     Age  Gender
# 0    45    Male
# 1    23  Female
# 2    27    Male
# 3    34    Male
# 4    43  Female
# 5    34    Male
# 6    44  Female
# 7    56  Female
# 8    34    Male
# 9    49  Female
# 10   35    Male
# 11   28  Female
# 12   54    Male
# 13   59  Female
# 14   54    Male
# 15   43  Female
# 16   56  Female
# 17   41    Male
# 18   56    Male
# 19   53    Male
# 20   21  Female

# %%
d2
# Out:
#      Hometown  Height
# 0      Mumbai     167
# 1      Mumbai     170
# 2      Mumbai     175
# 3       Delhi     155
# 4      Mumbai     157
# 5       Delhi     167
# 6      Mumbai     165
# 7       Delhi     170
# 8       Delhi     175
# 9   Bangalore     162
# 10  Bangalore     160
# 11     Mumbai     165
# 12      Delhi     170
# 13     Mumbai     175
# 14  Bangalore     175
# 15     Mumbai     155
# 16     Mumbai     151
# 17  Bangalore     180
# 18      Delhi     182
# 19  Bangalore     156
# 20  Bangalore     158

# %%
pd.concat([d1,d2],axis=1)
# Out:
#     Age  Gender   Hometown  Height
# 0    45    Male     Mumbai     167
# 1    23  Female     Mumbai     170
# 2    27    Male     Mumbai     175
# 3    34    Male      Delhi     155
# 4    43  Female     Mumbai     157
# 5    34    Male      Delhi     167
# 6    44  Female     Mumbai     165
# 7    56  Female      Delhi     170
# 8    34    Male      Delhi     175
# 9    49  Female  Bangalore     162
# 10   35    Male  Bangalore     160
# 11   28  Female     Mumbai     165
# 12   54    Male      Delhi     170
# 13   59  Female     Mumbai     175
# 14   54    Male  Bangalore     175
# 15   43  Female     Mumbai     155
# 16   56  Female     Mumbai     151
# 17   41    Male  Bangalore     180
# 18   56    Male      Delhi     182
# 19   53    Male  Bangalore     156
# 20   21  Female  Bangalore     158

# %%
data.head()
# Out:
#    Age  Gender Hometown  Height  Qualification Smoker
# 0   45    Male   Mumbai     167       Graduate    Yes
# 1   23  Female   Mumbai     170       Graduate     No
# 2   27    Male   Mumbai     175  Post-graduate     No
# 3   34    Male    Delhi     155       Graduate     No
# 4   43  Female   Mumbai     157  Post-graduate    Yes

# %%
what are the unique values of hometown in your data. Map it with the state names respectively.

# %%
data['Hometown'].unique()
# Out:
# array(['Mumbai', 'Delhi', 'Bangalore'], dtype=object)

# %%
state={'Mumbai':'Maharashtra','Delhi':'Delhi State','Bangalore':'Karnataka'}

# %%
data['States']=data['Hometown'].map(state)

# %%
data
# Out:
#     Age  Gender   Hometown  Height  Qualification Smoker       States
# 0    45    Male     Mumbai     167       Graduate    Yes  Maharashtra
# 1    23  Female     Mumbai     170       Graduate     No  Maharashtra
# 2    27    Male     Mumbai     175  Post-graduate     No  Maharashtra
# 3    34    Male      Delhi     155       Graduate     No  Delhi State
# 4    43  Female     Mumbai     157  Post-graduate    Yes  Maharashtra
# 5    34    Male      Delhi     167        Diploma    Yes  Delhi State
# 6    44  Female     Mumbai     165       Graduate    Yes  Maharashtra
# 7    56  Female      Delhi     170        Diploma    Yes  Delhi State
# 8    34    Male      Delhi     175  Post-graduate     No  Delhi State
# 9    49  Female  Bangalore     162  Post-graduate    Yes    Karnataka
# 10   35    Male  Bangalore     160       Graduate     No    Karnataka
# 11   28  Female     Mumbai     165        Diploma     No  Maharashtra
# ...

# %%
replace the word Female with 'f' and male with the letter 'm ' in you data frame
# Out:
#   File "<ipython-input-30-0b98d71246ff>", line 1
#     replace the word Female with 'f' and male with the letter 'm ' in you data frame
#             ^
# SyntaxError: invalid syntax

# %%
data.head(2)
# Out:
#    Age  Gender Hometown  Height Qualification Smoker       States
# 0   45    Male   Mumbai     167      Graduate    Yes  Maharashtra
# 1   23  Female   Mumbai     170      Graduate     No  Maharashtra

# %%
data['Gender']=data['Gender'].replace('Male','m')

# %%
data['Gender']=data['Gender'].replace('Female','f')

# %%
data
# Out:
#     Age Gender   Hometown  Height  Qualification Smoker       States
# 0    45      m     Mumbai     167       Graduate    Yes  Maharashtra
# 1    23      f     Mumbai     170       Graduate     No  Maharashtra
# 2    27      m     Mumbai     175  Post-graduate     No  Maharashtra
# 3    34      m      Delhi     155       Graduate     No  Delhi State
# 4    43      f     Mumbai     157  Post-graduate    Yes  Maharashtra
# 5    34      m      Delhi     167        Diploma    Yes  Delhi State
# 6    44      f     Mumbai     165       Graduate    Yes  Maharashtra
# 7    56      f      Delhi     170        Diploma    Yes  Delhi State
# 8    34      m      Delhi     175  Post-graduate     No  Delhi State
# 9    49      f  Bangalore     162  Post-graduate    Yes    Karnataka
# 10   35      m  Bangalore     160       Graduate     No    Karnataka
# 11   28      f     Mumbai     165        Diploma     No  Maharashtra
# 12   54      m      Delhi     170        Diploma    Yes  Delhi State
# ...

# %%
data.head()
# Out:
#    Age Gender Hometown  Height  Qualification Smoker       States
# 0   45      m   Mumbai     167       Graduate    Yes  Maharashtra
# 1   23      f   Mumbai     170       Graduate     No  Maharashtra
# 2   27      m   Mumbai     175  Post-graduate     No  Maharashtra
# 3   34      m    Delhi     155       Graduate     No  Delhi State
# 4   43      f   Mumbai     157  Post-graduate    Yes  Maharashtra

# %% [markdown]
# using pandas crosstab, calculate how many graduates and post graduates are coming from different states?

# %%
abc=pd.crosstab(data['Qualification'],data['States'])

# %%
abc
# Out:
# States         Delhi State  Karnataka  Maharashtra
# Qualification
# Diploma                  3          2            1
# Graduate                 2          1            5
# Post-graduate            1          3            3

# %%
abc.loc['Graduate'].sum()
# Out:
# 8

# %%
data.head()
# Out:
#    Age Gender Hometown  Height  Qualification Smoker       States
# 0   45      m   Mumbai     167       Graduate    Yes  Maharashtra
# 1   23      f   Mumbai     170       Graduate     No  Maharashtra
# 2   27      m   Mumbai     175  Post-graduate     No  Maharashtra
# 3   34      m    Delhi     155       Graduate     No  Delhi State
# 4   43      f   Mumbai     157  Post-graduate    Yes  Maharashtra

# %%
what is the average age of people from bangalore city?

# %%
data[data['Hometown']=='Bangalore']['Age'].mean()
# Out:
# 42.166666666666664

# %%
abc1=pd.pivot_table(data,index=['Hometown'],values=['Age'],aggfunc=np.mean)

# %%
abc1
# Out:
#                  Age
# Hometown
# Bangalore  42.166667
# Delhi      44.666667
# Mumbai     40.888889

# %%
abc1.loc['Bangalore']
# Out:
# Age    42.166667
# Name: Bangalore, dtype: float64

# %%
a=data.groupby('Hometown')['Age'].mean()

# %%
a
# Out:
# Hometown
# Bangalore    42.166667
# Delhi        44.666667
# Mumbai       40.888889
# Name: Age, dtype: float64

# %%
a.loc['Bangalore']
# Out:
# 42.166666666666664

# %%
data.head()
# Out:
#    Age Gender Hometown  Height  Qualification Smoker       States
# 0   45      m   Mumbai     167       Graduate    Yes  Maharashtra
# 1   23      f   Mumbai     170       Graduate     No  Maharashtra
# 2   27      m   Mumbai     175  Post-graduate     No  Maharashtra
# 3   34      m    Delhi     155       Graduate     No  Delhi State
# 4   43      f   Mumbai     157  Post-graduate    Yes  Maharashtra

# %%
find out the rows in your dataset which are duplicated.

# %%
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Age, Gender, Hometown, Height, Qualification, Smoker, States]
# Index: []

# %%
there are no duplicate rows in my dataset.

# %%
how will you transpose the rows and columns in your dataset? what are the diff methods

# %%
data.T
# Out:
#                         0            1              2            3   \
# Age                     45           23             27           34
# Gender                   m            f              m            m
# Hometown            Mumbai       Mumbai         Mumbai        Delhi
# Height                 167          170            175          155
# Qualification     Graduate     Graduate  Post-graduate     Graduate
# Smoker                 Yes           No             No           No
# States         Maharashtra  Maharashtra    Maharashtra  Delhi State
#
#                           4            5            6            7   \
# Age                       43           34           44           56
# Gender                     f            m            f            f
# Hometown              Mumbai        Delhi       Mumbai        Delhi
# Height                   157          167          165          170
# Qualification  Post-graduate      Diploma     Graduate      Diploma
# ...

# %%
data.transpose()
# Out:
#                         0            1              2            3   \
# Age                     45           23             27           34
# Gender                   m            f              m            m
# Hometown            Mumbai       Mumbai         Mumbai        Delhi
# Height                 167          170            175          155
# Qualification     Graduate     Graduate  Post-graduate     Graduate
# Smoker                 Yes           No             No           No
# States         Maharashtra  Maharashtra    Maharashtra  Delhi State
#
#                           4            5            6            7   \
# Age                       43           34           44           56
# Gender                     f            m            f            f
# Hometown              Mumbai        Delhi       Mumbai        Delhi
# Height                   157          167          165          170
# Qualification  Post-graduate      Diploma     Graduate      Diploma
# ...

# %%
data.head(2)
# Out:
#    Age Gender Hometown  Height Qualification Smoker       States
# 0   45      m   Mumbai     167      Graduate    Yes  Maharashtra
# 1   23      f   Mumbai     170      Graduate     No  Maharashtra

# %%
find out the total number of null values in each column?

# %%
data.isnull().sum()
# Out:
# Age              0
# Gender           0
# Hometown         0
# Height           0
# Qualification    0
# Smoker           0
# States           0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Age            21 non-null     int64
#  1   Gender         21 non-null     object
#  2   Hometown       21 non-null     object
#  3   Height         21 non-null     int64
#  4   Qualification  21 non-null     object
#  5   Smoker         21 non-null     object
#  6   States         21 non-null     object
# dtypes: int64(2), object(5)
# memory usage: 1.3+ KB

# %%
data[data.isnull()].count()
# Out:
# Age              0
# Gender           0
# Hometown         0
# Height           0
# Qualification    0
# Smoker           0
# States           0
# dtype: int64

# %%
convert the datatype of age column from int64 to float64.

# %%
data['Age'].astype(np.float64)
# Out:
# 0     45.0
# 1     23.0
# 2     27.0
# 3     34.0
# 4     43.0
# 5     34.0
# 6     44.0
# 7     56.0
# 8     34.0
# 9     49.0
# 10    35.0
# 11    28.0
# 12    54.0
# 13    59.0
# 14    54.0
# 15    43.0
# 16    56.0
# 17    41.0
# 18    56.0
# 19    53.0
# 20    21.0
# Name: Age, dtype: float64

# %%
using the .apply method of pandas find out the squares of age /height-6
using .iloc operation show various ways of extracting the data.-6

# %%
def sqr(num):
    return pow(num,2)

# %%
data['Age'].apply(sqr)
# Out:
# 0     2025
# 1      529
# 2      729
# 3     1156
# 4     1849
# 5     1156
# 6     1936
# 7     3136
# 8     1156
# 9     2401
# 10    1225
# 11     784
# 12    2916
# 13    3481
# 14    2916
# 15    1849
# 16    3136
# 17    1681
# 18    3136
# 19    2809
# 20     441
# Name: Age, dtype: int64

# %%
data['Age'].apply(lambda num:num**2)
# Out:
# 0     2025
# 1      529
# 2      729
# 3     1156
# 4     1849
# 5     1156
# 6     1936
# 7     3136
# 8     1156
# 9     2401
# 10    1225
# 11     784
# 12    2916
# 13    3481
# 14    2916
# 15    1849
# 16    3136
# 17    1681
# 18    3136
# 19    2809
# 20     441
# Name: Age, dtype: int64

# %%
data["Age"].apply(np.square)
# Out:
# 0     2025
# 1      529
# 2      729
# 3     1156
# 4     1849
# 5     1156
# 6     1936
# 7     3136
# 8     1156
# 9     2401
# 10    1225
# 11     784
# 12    2916
# 13    3481
# 14    2916
# 15    1849
# 16    3136
# 17    1681
# 18    3136
# 19    2809
# 20     441
# Name: Age, dtype: int64

# %%
data.head()
# Out:
#    Age Gender Hometown  Height  Qualification Smoker       States
# 0   45      m   Mumbai     167       Graduate    Yes  Maharashtra
# 1   23      f   Mumbai     170       Graduate     No  Maharashtra
# 2   27      m   Mumbai     175  Post-graduate     No  Maharashtra
# 3   34      m    Delhi     155       Graduate     No  Delhi State
# 4   43      f   Mumbai     157  Post-graduate    Yes  Maharashtra

# %%
using pandas a apply method convert the data points of smoker to lowercase data.save

# %%
def string(data):
    return data.lower()

# %%
data['Smoker']=data['Smoker'].apply(string)
# Out:
# 0     yes
# 1      no
# 2      no
# 3      no
# 4     yes
# 5     yes
# 6     yes
# 7     yes
# 8      no
# 9     yes
# 10     no
# 11     no
# 12    yes
# 13     no
# 14    yes
# 15     no
# 16     no
# 17     no
# 18    yes
# 19    yes
# 20     no
# Name: Smoker, dtype: object

# %%
data['Smoker'].apply(str.lower)
# Out:
# 0     yes
# 1      no
# 2      no
# 3      no
# 4     yes
# 5     yes
# 6     yes
# 7     yes
# 8      no
# 9     yes
# 10     no
# 11     no
# 12    yes
# 13     no
# 14    yes
# 15     no
# 16     no
# 17     no
# 18    yes
# 19    yes
# 20     no
# Name: Smoker, dtype: object

# %%
data['Smoker'].apply(lambda data:data.lower())
# Out:
# 0     yes
# 1      no
# 2      no
# 3      no
# 4     yes
# 5     yes
# 6     yes
# 7     yes
# 8      no
# 9     yes
# 10     no
# 11     no
# 12    yes
# 13     no
# 14    yes
# 15     no
# 16     no
# 17     no
# 18    yes
# 19    yes
# 20     no
# Name: Smoker, dtype: object

# %%
data.head()
# Out:
#    Age Gender Hometown  Height  Qualification Smoker       States
# 0   45      m   Mumbai     167       Graduate    Yes  Maharashtra
# 1   23      f   Mumbai     170       Graduate     No  Maharashtra
# 2   27      m   Mumbai     175  Post-graduate     No  Maharashtra
# 3   34      m    Delhi     155       Graduate     No  Delhi State
# 4   43      f   Mumbai     157  Post-graduate    Yes  Maharashtra

# %%
data.iloc[0]
# Out:
# Age                    45
# Gender               Male
# Hometown           Mumbai
# Height                167
# Qualification    Graduate
# Smoker                Yes
# Name: 0, dtype: object

# %%
data.iloc[0:2,0:1]
# Out:
#    Age
# 0   45
# 1   23

# %%
data.iloc[0:2]['Age']
# Out:
# 0    45
# 1    23
# Name: Age, dtype: int64

# %%
data.head()
# Out:
#    Age Gender Hometown  Height  Qualification Smoker       States
# 0   45      m   Mumbai     167       Graduate    Yes  Maharashtra
# 1   23      f   Mumbai     170       Graduate     No  Maharashtra
# 2   27      m   Mumbai     175  Post-graduate     No  Maharashtra
# 3   34      m    Delhi     155       Graduate     No  Delhi State
# 4   43      f   Mumbai     157  Post-graduate    Yes  Maharashtra

# %% [raw]
# what is the best method of pulling out the data of non smokers in the city of Delhi above 25 years of age with a min height of 157 cm?-6

# %%
data[(data['Smoker']=='No') &(data['Hometown']=='Delhi')&(data['Age']>25)&(data['Height']>=157)]
# Out:
#    Age Gender Hometown  Height  Qualification Smoker       States
# 8   34      m    Delhi     175  Post-graduate     No  Delhi State

# %%
df_prof_info_A = pd.DataFrame({
   'Emp_ID': [1001,1002,1003,1004,1005],
   'Name': ['Alex', 'Amy', 'Allen', 'Alice', 'Stephan'],
   'Gender':['M', 'F', 'M', 'F', 'M'],
   'Company':['Apple','Walmart','Intel','Cummins','Ford'],
   'Salary':[67000,90000,87000,69000,78000]},
   index=[101,102,103,104,105])

# %%
df_pers_info_A = pd.DataFrame({
     'Emp_ID': [1001,1002,1003,1004,1005],
   'Hometown': ['New York', 'London', 'San Francisco', 'Seattle', 'Madrid'],
     'Gender':['M', 'F', 'M', 'F', 'M'],
    'Marital':['Married','Divorsed','Single','Married','Single'],
   'Dependents':[1,1,3,2,1]},
   index=[101,102,103,104,105])

# %%
combine data frames by using duplicates column removed
# Out:
#   File "<ipython-input-38-70472ad8784f>", line 1
#     combine data frames by using duplicates column removed
#             ^
# SyntaxError: invalid syntax

# %%
df_pers_info_A
# Out:
#      Emp_ID       Hometown Gender   Marital  Dependents
# 101    1001       New York      M   Married           1
# 102    1002         London      F  Divorsed           1
# 103    1003  San Francisco      M    Single           3
# 104    1004        Seattle      F   Married           2
# 105    1005         Madrid      M    Single           1

# %%
df_prof_info_A
# Out:
#      Emp_ID     Name Gender  Company  Salary
# 101    1001     Alex      M    Apple   67000
# 102    1002      Amy      F  Walmart   90000
# 103    1003    Allen      M    Intel   87000
# 104    1004    Alice      F  Cummins   69000
# 105    1005  Stephan      M     Ford   78000

# %%
pd.concat([df_prof_info_A,df_pers_info_A],axis=1).T.drop_duplicates().T
# Out:
#     Emp_ID     Name Gender  Company Salary       Hometown   Marital Dependents
# 101   1001     Alex      M    Apple  67000       New York   Married          1
# 102   1002      Amy      F  Walmart  90000         London  Divorsed          1
# 103   1003    Allen      M    Intel  87000  San Francisco    Single          3
# 104   1004    Alice      F  Cummins  69000        Seattle   Married          2
# 105   1005  Stephan      M     Ford  78000         Madrid    Single          1

# %%
header=pd.MultiIndex.from_product([['India','us'],['Corona cured','corona active']])

# %%
data=[[23,34,56,78],[23,54,67,100]]

# %%
pd.DataFrame(data,columns=header,index=['A','B'])
# Out:
#          India                         us
#   Corona cured corona active Corona cured corona active
# A           23            34           56            78
# B           23            54           67           100

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data.head()
# Out:
#    Age Gender Hometown  Height  Qualification Smoker       States
# 0   45      m   Mumbai     167       Graduate    Yes  Maharashtra
# 1   23      f   Mumbai     170       Graduate     No  Maharashtra
# 2   27      m   Mumbai     175  Post-graduate     No  Maharashtra
# 3   34      m    Delhi     155       Graduate     No  Delhi State
# 4   43      f   Mumbai     157  Post-graduate    Yes  Maharashtra

# %%
data['Gender'].value_counts()
# Out:
# m    11
# f    10
# Name: Gender, dtype: int64

# %%
sns.countplot(x='Hometown',data=data,hue='Gender',color='gold')

# %%
data.head()
# Out:
#    Age  Gender Hometown  Height  Qualification Smoker
# 0   45    Male   Mumbai     167       Graduate    Yes
# 1   23  Female   Mumbai     170       Graduate     No
# 2   27    Male   Mumbai     175  Post-graduate     No
# 3   34    Male    Delhi     155       Graduate     No
# 4   43  Female   Mumbai     157  Post-graduate    Yes

# %%
# scatter plot can only take numerical conti values

# %%
sns.scatterplot(x='Age',y='Age',data=data,color='b')
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Age'>

# %%
sns.distplot(data['Age'],kde=True)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Density'>
